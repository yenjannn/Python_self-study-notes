# %% [markdown]
# ## 機器學習III_UnsupervisedLearning&k_means

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
X = np.random.rand(100, 2)  # 一百筆，每一筆有兩個數字
X[0]
# Out:
# array([0.53540524, 0.87922369])

# %%
plt.scatter(X[:, 0], X[:, 1], s=50)

# %%
from sklearn.cluster import KMeans

# %%
clf = KMeans(n_clusters=3)

# %%
clf.fit(X)
# Out:
# KMeans(n_clusters=3)

# %%
clf.labels_
# Out:
# array([0, 2, 1, 0, 0, 0, 2, 1, 2, 0, 1, 2, 2, 1, 0, 1, 2, 2, 1, 2, 0, 2,
#        0, 0, 1, 1, 0, 0, 2, 2, 1, 0, 1, 0, 1, 2, 1, 1, 0, 2, 2, 1, 1, 1,
#        0, 2, 0, 1, 2, 0, 1, 2, 2, 1, 2, 1, 1, 1, 2, 0, 1, 2, 1, 1, 1, 1,
#        0, 1, 1, 0, 0, 0, 1, 2, 2, 1, 0, 1, 0, 1, 1, 0, 0, 2, 2, 0, 1, 0,
#        1, 1, 0, 2, 1, 0, 2, 1, 2, 2, 2, 2])

# %%
clf.predict(X)
# Out:
# array([0, 2, 1, 0, 0, 0, 2, 1, 2, 0, 1, 2, 2, 1, 0, 1, 2, 2, 1, 2, 0, 2,
#        0, 0, 1, 1, 0, 0, 2, 2, 1, 0, 1, 0, 1, 2, 1, 1, 0, 2, 2, 1, 1, 1,
#        0, 2, 0, 1, 2, 0, 1, 2, 2, 1, 2, 1, 1, 1, 2, 0, 1, 2, 1, 1, 1, 1,
#        0, 1, 1, 0, 0, 0, 1, 2, 2, 1, 0, 1, 0, 1, 1, 0, 0, 2, 2, 0, 1, 0,
#        1, 1, 0, 2, 1, 0, 2, 1, 2, 2, 2, 2])

# %%
plt.scatter(X[:, 0], X[:, 1], c=clf.labels_)
